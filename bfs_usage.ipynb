# %%
# %load_ext autoreload
# %autoreload 2

# !gridrunner --world WumpusWorld  --entry bfs:BfsPlayer --horizon 200 data/wumpus_world_custom_02.json
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# this is  (3, 0)
# World details:
#   Size: (7, 7)
#   Pits: [(1, 1), (1, 2), (1, 3), (1, 4), (1, 5), (2, 5), (3, 5), (4, 5), (5, 5), (5, 4), (5, 3), (5, 2), (5, 1), (4, 1), (3, 1), (2, 1)]
#   Wumpus: [(3, 0)]
#   Gold: [(6, 5)]
#   Exits: [(0, 0)]
#   Blocks: []
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│  P│  P│  P│  P│ G │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│  P│  P│  P│  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │W  │   │   │   │
# ...
