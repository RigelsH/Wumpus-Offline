# %%
import sys
sys.path.append("../")

import wumpus
import json
from bfs import BfsPlayer
import glob
from collections import defaultdict

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
files = glob.glob("../data/*")

result = defaultdict()

for file in sorted(files):
    with open(file) as f:
        world_json = json.load(f)

        episode_result = wumpus.run_episode(
            world=wumpus.WumpusWorld.from_JSON(world_json), 
            player=BfsPlayer(), 
            show=False, 
            horizon=1000
        )

        result[file] = episode_result['reward']
# Out:
# this is  (1, 7)
# World details:
#   Size: (8, 8)
#   Pits: [(7, 1), (1, 3), (3, 3), (4, 3), (6, 3), (4, 4), (7, 4), (5, 6), (7, 6), (3, 7), (5, 7)]
#   Wumpus: [(1, 7)]
#   Gold: [(3, 2)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fd8eb executing MOVE -> reward -1
# Step 1: agent Hunter_118fd8eb executing MOVE -> reward -1
# Step 2: agent Hunter_118fd8eb executing RIGHT -> reward -1
# Step 3: agent Hunter_118fd8eb executing MOVE -> reward -1
# Step 4: agent Hunter_118fd8eb executing MOVE -> reward -1
# Step 5: agent Hunter_118fd8eb executing MOVE -> reward -1
# Step 6: agent Hunter_118fd8eb executing GRAB -> reward -1
# Step 7: agent Hunter_118fd8eb executing RIGHT -> reward -1
# Step 8: agent Hunter_118fd8eb executing RIGHT -> reward -1
# Step 9: agent Hunter_118fd8eb executing MOVE -> reward -1
# Step 10: agent Hunter_118fd8eb executing MOVE -> reward -1
# Step 11: agent Hunter_118fd8eb executing MOVE -> reward -1
# Step 12: agent Hunter_118fd8eb executing LEFT -> reward -1
# Step 13: agent Hunter_118fd8eb executing MOVE -> reward -1
# Step 14: agent Hunter_118fd8eb executing MOVE -> reward -1
# Step 15: agent Hunter_118fd8eb executing CLIMB -> reward 999
# The agent Hunter_118fd8eb succeeded!
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │W  │   │  P│   │  P│   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │  P│   │  P│
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │  P│   │   │  P│
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │  P│  P│   │  P│   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │  P│
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │ @V│   │   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 984 for agent Hunter_118fd8eb
# this is  (2, 2)
# World details:
#   Size: (6, 6)
#   Pits: [(3, 0), (2, 1), (4, 2), (0, 3), (1, 3), (3, 4), (4, 4), (5, 4)]
#   Wumpus: [(2, 2)]
#   Gold: [(3, 1)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118c2876 executing MOVE -> reward -1
# Step 1: agent Hunter_118c2876 executing MOVE -> reward -1
# Step 2: agent Hunter_118c2876 executing RIGHT -> reward -1
# Step 3: agent Hunter_118c2876 executing MOVE -> reward -1
# Step 4: agent Hunter_118c2876 executing SHOOT -> reward -10
# Step 5: agent Hunter_118c2876 executing MOVE -> reward -1
# Step 6: agent Hunter_118c2876 executing MOVE -> reward -1
# Step 7: agent Hunter_118c2876 executing RIGHT -> reward -1
# Step 8: agent Hunter_118c2876 executing MOVE -> reward -1
# Step 9: agent Hunter_118c2876 executing GRAB -> reward -1
# Step 10: agent Hunter_118c2876 executing RIGHT -> reward -1
# Step 11: agent Hunter_118c2876 executing RIGHT -> reward -1
# Step 12: agent Hunter_118c2876 executing MOVE -> reward -1
# Step 13: agent Hunter_118c2876 executing LEFT -> reward -1
# Step 14: agent Hunter_118c2876 executing MOVE -> reward -1
# Step 15: agent Hunter_118c2876 executing MOVE -> reward -1
# Step 16: agent Hunter_118c2876 executing MOVE -> reward -1
# Step 17: agent Hunter_118c2876 executing LEFT -> reward -1
# Step 18: agent Hunter_118c2876 executing MOVE -> reward -1
# Step 19: agent Hunter_118c2876 executing MOVE -> reward -1
# Step 20: agent Hunter_118c2876 executing CLIMB -> reward 999
# The agent Hunter_118c2876 succeeded!
# ┌───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │  P│  P│  P│
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │  P│  P│   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │  P│   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │  P│   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │  P│   │   │
# │ @V│   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 970 for agent Hunter_118c2876
# this is  (3, 4)
# World details:
#   Size: (5, 5)
#   Pits: [(3, 0), (1, 1), (3, 1), (0, 2), (3, 2), (4, 2), (4, 4)]
#   Wumpus: [(3, 4)]
#   Gold: [(1, 2)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fdb9d executing RIGHT -> reward -1
# Step 1: agent Hunter_118fdb9d executing MOVE -> reward -1
# Step 2: agent Hunter_118fdb9d executing MOVE -> reward -1
# Step 3: agent Hunter_118fdb9d executing LEFT -> reward -1
# Step 4: agent Hunter_118fdb9d executing MOVE -> reward -1
# Step 5: agent Hunter_118fdb9d executing MOVE -> reward -1
# Step 6: agent Hunter_118fdb9d executing LEFT -> reward -1
# Step 7: agent Hunter_118fdb9d executing MOVE -> reward -1
# Step 8: agent Hunter_118fdb9d executing GRAB -> reward -1
# Step 9: agent Hunter_118fdb9d executing RIGHT -> reward -1
# Step 10: agent Hunter_118fdb9d executing RIGHT -> reward -1
# Step 11: agent Hunter_118fdb9d executing MOVE -> reward -1
# Step 12: agent Hunter_118fdb9d executing RIGHT -> reward -1
# Step 13: agent Hunter_118fdb9d executing MOVE -> reward -1
# Step 14: agent Hunter_118fdb9d executing MOVE -> reward -1
# Step 15: agent Hunter_118fdb9d executing RIGHT -> reward -1
# Step 16: agent Hunter_118fdb9d executing MOVE -> reward -1
# Step 17: agent Hunter_118fdb9d executing MOVE -> reward -1
# Step 18: agent Hunter_118fdb9d executing CLIMB -> reward 999
# The agent Hunter_118fdb9d succeeded!
# ┌───┬───┬───┬───┬───┐
# │   │   │   │W  │  P│
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │  P│   │   │  P│  P│
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │  P│   │  P│   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │  P│   │
# │ @<│   │   │   │   │
# └───┴───┴───┴───┴───┘
# Episode terminated with a reward of 981 for agent Hunter_118fdb9d
# this is  (2, 0)
# World details:
#   Size: (4, 4)
#   Pits: [(1, 0), (2, 1)]
#   Wumpus: [(2, 0)]
#   Gold: [(2, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fd94b executing MOVE -> reward -1
# Step 1: agent Hunter_118fd94b executing MOVE -> reward -1
# Step 2: agent Hunter_118fd94b executing RIGHT -> reward -1
# Step 3: agent Hunter_118fd94b executing MOVE -> reward -1
# Step 4: agent Hunter_118fd94b executing MOVE -> reward -1
# Step 5: agent Hunter_118fd94b executing LEFT -> reward -1
# Step 6: agent Hunter_118fd94b executing MOVE -> reward -1
# Step 7: agent Hunter_118fd94b executing GRAB -> reward -1
# Step 8: agent Hunter_118fd94b executing RIGHT -> reward -1
# Step 9: agent Hunter_118fd94b executing RIGHT -> reward -1
# Step 10: agent Hunter_118fd94b executing MOVE -> reward -1
# Step 11: agent Hunter_118fd94b executing RIGHT -> reward -1
# Step 12: agent Hunter_118fd94b executing MOVE -> reward -1
# Step 13: agent Hunter_118fd94b executing MOVE -> reward -1
# Step 14: agent Hunter_118fd94b executing LEFT -> reward -1
# Step 15: agent Hunter_118fd94b executing MOVE -> reward -1
# Step 16: agent Hunter_118fd94b executing MOVE -> reward -1
# Step 17: agent Hunter_118fd94b executing CLIMB -> reward 999
# The agent Hunter_118fd94b succeeded!
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │  P│W  │   │
# │ @V│   │   │   │
# └───┴───┴───┴───┘
# Episode terminated with a reward of 982 for agent Hunter_118fd94b
# this is  (2, 2)
# World details:
#   Size: (4, 4)
#   Pits: [(2, 0), (0, 1), (3, 1), (2, 2), (3, 3)]
#   Wumpus: [(2, 2)]
#   Gold: [(2, 0)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fdb2e executing CLIMB -> reward -1
# The agent Hunter_118fdb2e succeeded!
# ┌───┬───┬───┬───┐
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │W P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │  P│   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │ GP│   │
# │ @^│   │   │   │
# └───┴───┴───┴───┘
# Episode terminated with a reward of -1 for agent Hunter_118fdb2e
# this is  (5, 1)
# World details:
#   Size: (6, 6)
#   Pits: [(3, 2), (4, 2), (5, 3), (4, 4)]
#   Wumpus: [(5, 1)]
#   Gold: [(4, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 1: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 2: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 3: agent Hunter_118fdb64 executing RIGHT -> reward -1
# Step 4: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 5: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 6: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 7: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 8: agent Hunter_118fdb64 executing GRAB -> reward -1
# Step 9: agent Hunter_118fdb64 executing RIGHT -> reward -1
# Step 10: agent Hunter_118fdb64 executing RIGHT -> reward -1
# Step 11: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 12: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 13: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 14: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 15: agent Hunter_118fdb64 executing LEFT -> reward -1
# Step 16: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 17: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 18: agent Hunter_118fdb64 executing MOVE -> reward -1
# Step 19: agent Hunter_118fdb64 executing CLIMB -> reward 999
# The agent Hunter_118fdb64 succeeded!
# ┌───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │  P│   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │  P│
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │  P│  P│   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │W  │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │
# │ @V│   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 980 for agent Hunter_118fdb64
# this is  (0, 3)
# World details:
#   Size: (5, 5)
#   Pits: [(2, 0), (3, 0), (0, 2), (4, 2), (4, 3)]
#   Wumpus: [(0, 3)]
#   Gold: [(2, 4)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 1: agent Hunter_118fdb76 executing RIGHT -> reward -1
# Step 2: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 3: agent Hunter_118fdb76 executing LEFT -> reward -1
# Step 4: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 5: agent Hunter_118fdb76 executing RIGHT -> reward -1
# Step 6: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 7: agent Hunter_118fdb76 executing LEFT -> reward -1
# Step 8: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 9: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 10: agent Hunter_118fdb76 executing GRAB -> reward -1
# Step 11: agent Hunter_118fdb76 executing RIGHT -> reward -1
# Step 12: agent Hunter_118fdb76 executing RIGHT -> reward -1
# Step 13: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 14: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 15: agent Hunter_118fdb76 executing RIGHT -> reward -1
# Step 16: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 17: agent Hunter_118fdb76 executing LEFT -> reward -1
# Step 18: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 19: agent Hunter_118fdb76 executing RIGHT -> reward -1
# Step 20: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 21: agent Hunter_118fdb76 executing LEFT -> reward -1
# Step 22: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 23: agent Hunter_118fdb76 executing CLIMB -> reward 999
# The agent Hunter_118fdb76 succeeded!
# ┌───┬───┬───┬───┬───┐
# │   │   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │W  │   │   │   │  P│
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │  P│   │   │   │  P│
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │  P│  P│   │
# │ @V│   │   │   │   │
# └───┴───┴───┴───┴───┘
# Episode terminated with a reward of 976 for agent Hunter_118fdb76
# this is  (3, 0)
# World details:
#   Size: (6, 6)
#   Pits: [(3, 1), (5, 1), (0, 2), (0, 3), (2, 5)]
#   Wumpus: [(3, 0)]
#   Gold: [(3, 1)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fdb6d executing CLIMB -> reward -1
# The agent Hunter_118fdb6d succeeded!
# ┌───┬───┬───┬───┬───┬───┐
# │   │   │  P│   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │  P│   │   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │  P│   │   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │ GP│   │  P│
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │W  │   │   │
# │ @^│   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of -1 for agent Hunter_118fdb6d
# this is  (0, 3)
# World details:
#   Size: (5, 5)
#   Pits: [(3, 3), (0, 4)]
#   Wumpus: [(0, 3)]
#   Gold: [(2, 2)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fd8b2 executing MOVE -> reward -1
# Step 1: agent Hunter_118fd8b2 executing RIGHT -> reward -1
# Step 2: agent Hunter_118fd8b2 executing MOVE -> reward -1
# Step 3: agent Hunter_118fd8b2 executing MOVE -> reward -1
# Step 4: agent Hunter_118fd8b2 executing LEFT -> reward -1
# Step 5: agent Hunter_118fd8b2 executing MOVE -> reward -1
# Step 6: agent Hunter_118fd8b2 executing GRAB -> reward -1
# Step 7: agent Hunter_118fd8b2 executing RIGHT -> reward -1
# Step 8: agent Hunter_118fd8b2 executing RIGHT -> reward -1
# Step 9: agent Hunter_118fd8b2 executing MOVE -> reward -1
# Step 10: agent Hunter_118fd8b2 executing RIGHT -> reward -1
# Step 11: agent Hunter_118fd8b2 executing MOVE -> reward -1
# Step 12: agent Hunter_118fd8b2 executing MOVE -> reward -1
# Step 13: agent Hunter_118fd8b2 executing LEFT -> reward -1
# Step 14: agent Hunter_118fd8b2 executing MOVE -> reward -1
# Step 15: agent Hunter_118fd8b2 executing CLIMB -> reward 999
# The agent Hunter_118fd8b2 succeeded!
# ┌───┬───┬───┬───┬───┐
# │  P│   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │W  │   │   │  P│   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │   │
# │ @V│   │   │   │   │
# └───┴───┴───┴───┴───┘
# Episode terminated with a reward of 984 for agent Hunter_118fd8b2
# this is  (1, 2)
# World details:
#   Size: (7, 7)
#   Pits: [(2, 0), (4, 6)]
#   Wumpus: [(1, 2)]
#   Gold: [(2, 5)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 1: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 2: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 3: agent Hunter_118fd870 executing RIGHT -> reward -1
# Step 4: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 5: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 6: agent Hunter_118fd870 executing LEFT -> reward -1
# Step 7: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 8: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 9: agent Hunter_118fd870 executing GRAB -> reward -1
# Step 10: agent Hunter_118fd870 executing RIGHT -> reward -1
# Step 11: agent Hunter_118fd870 executing RIGHT -> reward -1
# Step 12: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 13: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 14: agent Hunter_118fd870 executing RIGHT -> reward -1
# Step 15: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 16: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 17: agent Hunter_118fd870 executing LEFT -> reward -1
# Step 18: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 19: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 20: agent Hunter_118fd870 executing MOVE -> reward -1
# Step 21: agent Hunter_118fd870 executing CLIMB -> reward 999
# The agent Hunter_118fd870 succeeded!
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │  P│   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │W  │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │  P│   │   │   │   │
# │ @V│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 978 for agent Hunter_118fd870
# this is  (0, 5)
# World details:
#   Size: (6, 6)
#   Pits: [(1, 1), (1, 2), (1, 3), (1, 4), (3, 1), (4, 1), (5, 2), (2, 3), (3, 3), (4, 4), (5, 4)]
#   Wumpus: [(0, 5)]
#   Gold: [(5, 5)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 1: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 2: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 3: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 4: agent Hunter_118fd8d6 executing SHOOT -> reward -10
# Step 5: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 6: agent Hunter_118fd8d6 executing RIGHT -> reward -1
# Step 7: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 8: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 9: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 10: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 11: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 12: agent Hunter_118fd8d6 executing GRAB -> reward -1
# Step 13: agent Hunter_118fd8d6 executing RIGHT -> reward -1
# Step 14: agent Hunter_118fd8d6 executing RIGHT -> reward -1
# Step 15: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 16: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 17: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 18: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 19: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 20: agent Hunter_118fd8d6 executing LEFT -> reward -1
# Step 21: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 22: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 23: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 24: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 25: agent Hunter_118fd8d6 executing MOVE -> reward -1
# Step 26: agent Hunter_118fd8d6 executing CLIMB -> reward 999
# The agent Hunter_118fd8d6 succeeded!
# ┌───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │  P│  P│
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │  P│  P│  P│   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │  P│   │  P│  P│   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │
# │ @V│   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 964 for agent Hunter_118fd8d6
# this is  (0, 1)
# World details:
#   Size: (4, 4)
#   Pits: [(1, 1), (1, 2)]
#   Wumpus: [(0, 1)]
#   Gold: [(0, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fdba0 executing SHOOT -> reward -10
# Step 1: agent Hunter_118fdba0 executing MOVE -> reward -1
# Step 2: agent Hunter_118fdba0 executing MOVE -> reward -1
# Step 3: agent Hunter_118fdba0 executing MOVE -> reward -1
# Step 4: agent Hunter_118fdba0 executing GRAB -> reward -1
# Step 5: agent Hunter_118fdba0 executing RIGHT -> reward -1
# Step 6: agent Hunter_118fdba0 executing RIGHT -> reward -1
# Step 7: agent Hunter_118fdba0 executing MOVE -> reward -1
# Step 8: agent Hunter_118fdba0 executing MOVE -> reward -1
# Step 9: agent Hunter_118fdba0 executing MOVE -> reward -1
# Step 10: agent Hunter_118fdba0 executing CLIMB -> reward 999
# The agent Hunter_118fdba0 succeeded!
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │  P│   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │  P│   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @V│   │   │   │
# └───┴───┴───┴───┘
# Episode terminated with a reward of 980 for agent Hunter_118fdba0
# this is  (1, 3)
# World details:
#   Size: (7, 7)
#   Pits: [(1, 0), (3, 0), (0, 1), (3, 1)]
#   Wumpus: [(1, 3)]
#   Gold: [(2, 2)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fd85b executing CLIMB -> reward -1
# The agent Hunter_118fd85b succeeded!
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │W  │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │ G │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│   │   │  P│   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │  P│   │   │   │
# │ @^│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of -1 for agent Hunter_118fd85b
# this is  (3, 3)
# World details:
#   Size: (7, 7)
#   Pits: [(1, 1), (1, 2), (1, 3), (1, 4), (1, 5), (2, 5), (3, 5), (4, 5), (5, 5), (5, 4), (5, 3), (5, 2), (5, 1), (4, 1), (3, 1), (2, 1)]
#   Wumpus: [(3, 3)]
#   Gold: [(6, 6)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fdb76 executing RIGHT -> reward -1
# Step 1: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 2: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 3: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 4: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 5: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 6: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 7: agent Hunter_118fdb76 executing LEFT -> reward -1
# Step 8: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 9: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 10: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 11: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 12: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 13: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 14: agent Hunter_118fdb76 executing GRAB -> reward -1
# Step 15: agent Hunter_118fdb76 executing RIGHT -> reward -1
# Step 16: agent Hunter_118fdb76 executing RIGHT -> reward -1
# Step 17: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 18: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 19: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 20: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 21: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 22: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 23: agent Hunter_118fdb76 executing RIGHT -> reward -1
# Step 24: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 25: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 26: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 27: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 28: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 29: agent Hunter_118fdb76 executing MOVE -> reward -1
# Step 30: agent Hunter_118fdb76 executing CLIMB -> reward 999
# The agent Hunter_118fdb76 succeeded!
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│  P│  P│  P│  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │W  │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│  P│  P│  P│  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │ @<│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 969 for agent Hunter_118fdb76
# this is  (3, 0)
# World details:
#   Size: (7, 7)
#   Pits: [(1, 1), (1, 2), (1, 3), (1, 4), (1, 5), (2, 5), (3, 5), (4, 5), (5, 5), (5, 4), (5, 3), (5, 2), (5, 1), (4, 1), (3, 1), (2, 1)]
#   Wumpus: [(3, 0)]
#   Gold: [(6, 5)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118be292 executing MOVE -> reward -1
# Step 1: agent Hunter_118be292 executing MOVE -> reward -1
# Step 2: agent Hunter_118be292 executing MOVE -> reward -1
# Step 3: agent Hunter_118be292 executing MOVE -> reward -1
# Step 4: agent Hunter_118be292 executing MOVE -> reward -1
# Step 5: agent Hunter_118be292 executing MOVE -> reward -1
# Step 6: agent Hunter_118be292 executing RIGHT -> reward -1
# Step 7: agent Hunter_118be292 executing MOVE -> reward -1
# Step 8: agent Hunter_118be292 executing MOVE -> reward -1
# Step 9: agent Hunter_118be292 executing MOVE -> reward -1
# Step 10: agent Hunter_118be292 executing MOVE -> reward -1
# Step 11: agent Hunter_118be292 executing MOVE -> reward -1
# Step 12: agent Hunter_118be292 executing MOVE -> reward -1
# Step 13: agent Hunter_118be292 executing RIGHT -> reward -1
# Step 14: agent Hunter_118be292 executing MOVE -> reward -1
# Step 15: agent Hunter_118be292 executing GRAB -> reward -1
# Step 16: agent Hunter_118be292 executing RIGHT -> reward -1
# Step 17: agent Hunter_118be292 executing RIGHT -> reward -1
# Step 18: agent Hunter_118be292 executing MOVE -> reward -1
# Step 19: agent Hunter_118be292 executing LEFT -> reward -1
# Step 20: agent Hunter_118be292 executing MOVE -> reward -1
# Step 21: agent Hunter_118be292 executing MOVE -> reward -1
# Step 22: agent Hunter_118be292 executing MOVE -> reward -1
# Step 23: agent Hunter_118be292 executing MOVE -> reward -1
# Step 24: agent Hunter_118be292 executing MOVE -> reward -1
# Step 25: agent Hunter_118be292 executing MOVE -> reward -1
# Step 26: agent Hunter_118be292 executing LEFT -> reward -1
# Step 27: agent Hunter_118be292 executing MOVE -> reward -1
# Step 28: agent Hunter_118be292 executing MOVE -> reward -1
# Step 29: agent Hunter_118be292 executing MOVE -> reward -1
# Step 30: agent Hunter_118be292 executing MOVE -> reward -1
# Step 31: agent Hunter_118be292 executing MOVE -> reward -1
# Step 32: agent Hunter_118be292 executing MOVE -> reward -1
# Step 33: agent Hunter_118be292 executing CLIMB -> reward 999
# The agent Hunter_118be292 succeeded!
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│  P│  P│  P│  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│  P│  P│  P│  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │W  │   │   │   │
# │ @V│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 966 for agent Hunter_118be292
# this is  (0, 3)
# World details:
#   Size: (7, 7)
#   Pits: [(0, 1), (0, 2), (1, 2), (0, 3), (1, 3), (2, 3), (0, 4), (1, 4), (0, 5)]
#   Wumpus: [(0, 3)]
#   Gold: [(0, 6)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 1: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 2: agent Hunter_118fd80d executing LEFT -> reward -1
# Step 3: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 4: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 5: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 6: agent Hunter_118fd80d executing LEFT -> reward -1
# Step 7: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 8: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 9: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 10: agent Hunter_118fd80d executing LEFT -> reward -1
# Step 11: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 12: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 13: agent Hunter_118fd80d executing LEFT -> reward -1
# Step 14: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 15: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 16: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 17: agent Hunter_118fd80d executing LEFT -> reward -1
# Step 18: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 19: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 20: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 21: agent Hunter_118fd80d executing LEFT -> reward -1
# Step 22: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 23: agent Hunter_118fd80d executing GRAB -> reward -1
# Step 24: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 25: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 26: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 27: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 28: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 29: agent Hunter_118fd80d executing LEFT -> reward -1
# Step 30: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 31: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 32: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 33: agent Hunter_118fd80d executing LEFT -> reward -1
# Step 34: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 35: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 36: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 37: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 38: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 39: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 40: agent Hunter_118fd80d executing LEFT -> reward -1
# Step 41: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 42: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 43: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 44: agent Hunter_118fd80d executing LEFT -> reward -1
# Step 45: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 46: agent Hunter_118fd80d executing RIGHT -> reward -1
# Step 47: agent Hunter_118fd80d executing MOVE -> reward -1
# Step 48: agent Hunter_118fd80d executing CLIMB -> reward 999
# The agent Hunter_118fd80d succeeded!
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│  P│   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │W P│  P│  P│   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│  P│   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │ @<│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 951 for agent Hunter_118fd80d

# %%
dict(result)
# Out:
# {'../data/wumpus_world-00.json': 984,
#  '../data/wumpus_world-01.json': 970,
#  '../data/wumpus_world-02.json': 981,
#  '../data/wumpus_world-03.json': 982,
#  '../data/wumpus_world-04.json': -1,
#  '../data/wumpus_world-05.json': 980,
#  '../data/wumpus_world-06.json': 976,
#  '../data/wumpus_world-07.json': -1,
#  '../data/wumpus_world-08.json': 984,
#  '../data/wumpus_world-09.json': 978,
#  '../data/wumpus_world-kill_to_grab.json': 964,
#  '../data/wumpus_world-opt_kill.json': 980,
#  '../data/wumpus_world_custom_00.json': -1,
#  '../data/wumpus_world_custom_01.json': 969,
#  '../data/wumpus_world_custom_02.json': 966,
#  '../data/wumpus_world_custom_03.json': 951}
