# %%
import sys
sys.path.append("../")

import glob
from collections import defaultdict
import json
import wumpus
from astar import AstarPlayer
import time

# %%
files = glob.glob("../data/*")

result = defaultdict(list)

for file in sorted(files):
    start_time = time.perf_counter()    
    
    with open(file) as f:
        world_json = json.load(f)
        
        episode_result = wumpus.run_episode(
            world=wumpus.WumpusWorld.from_JSON(world_json), 
            player=AstarPlayer(), 
            show=False, 
            horizon=1000
        )
        
    end_time = time.perf_counter()    
    elapsed_time = (end_time - start_time)*1000  
    formatted_time = "{:.2f} ms".format(elapsed_time)
    
    result[file].append(formatted_time)
# Out:
# this is  (1, 7)
# World details:
#   Size: (8, 8)
#   Pits: [(7, 1), (1, 3), (3, 3), (4, 3), (6, 3), (4, 4), (7, 4), (5, 6), (7, 6), (3, 7), (5, 7)]
#   Wumpus: [(1, 7)]
#   Gold: [(3, 2)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96ced89a executing MOVE -> reward -1
# Step 1: agent Hunter_96ced89a executing MOVE -> reward -1
# Step 2: agent Hunter_96ced89a executing RIGHT -> reward -1
# Step 3: agent Hunter_96ced89a executing MOVE -> reward -1
# Step 4: agent Hunter_96ced89a executing MOVE -> reward -1
# Step 5: agent Hunter_96ced89a executing MOVE -> reward -1
# Step 6: agent Hunter_96ced89a executing GRAB -> reward -1
# Step 7: agent Hunter_96ced89a executing RIGHT -> reward -1
# Step 8: agent Hunter_96ced89a executing MOVE -> reward -1
# Step 9: agent Hunter_96ced89a executing MOVE -> reward -1
# Step 10: agent Hunter_96ced89a executing RIGHT -> reward -1
# Step 11: agent Hunter_96ced89a executing MOVE -> reward -1
# Step 12: agent Hunter_96ced89a executing MOVE -> reward -1
# Step 13: agent Hunter_96ced89a executing MOVE -> reward -1
# Step 14: agent Hunter_96ced89a executing CLIMB -> reward 999
# The agent Hunter_96ced89a succeeded!
# ┌───┬───┬───┬───┬───┬───┬───┬───┐
# │   │W  │   │  P│   │  P│   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │  P│   │  P│
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │  P│   │   │  P│
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │  P│  P│   │  P│   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │  P│
# │   │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │   │
# │ @<│   │   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 985 for agent Hunter_96ced89a
# this is  (2, 2)
# World details:
#   Size: (6, 6)
#   Pits: [(3, 0), (2, 1), (4, 2), (0, 3), (1, 3), (3, 4), (4, 4), (5, 4)]
#   Wumpus: [(2, 2)]
#   Gold: [(3, 1)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96ce8faf executing MOVE -> reward -1
# Step 1: agent Hunter_96ce8faf executing RIGHT -> reward -1
# Step 2: agent Hunter_96ce8faf executing MOVE -> reward -1
# Step 3: agent Hunter_96ce8faf executing LEFT -> reward -1
# Step 4: agent Hunter_96ce8faf executing MOVE -> reward -1
# Step 5: agent Hunter_96ce8faf executing RIGHT -> reward -1
# Step 6: agent Hunter_96ce8faf executing SHOOT -> reward -10
# Step 7: agent Hunter_96ce8faf executing MOVE -> reward -1
# Step 8: agent Hunter_96ce8faf executing MOVE -> reward -1
# Step 9: agent Hunter_96ce8faf executing RIGHT -> reward -1
# Step 10: agent Hunter_96ce8faf executing MOVE -> reward -1
# Step 11: agent Hunter_96ce8faf executing GRAB -> reward -1
# Step 12: agent Hunter_96ce8faf executing RIGHT -> reward -1
# Step 13: agent Hunter_96ce8faf executing RIGHT -> reward -1
# Step 14: agent Hunter_96ce8faf executing MOVE -> reward -1
# Step 15: agent Hunter_96ce8faf executing LEFT -> reward -1
# Step 16: agent Hunter_96ce8faf executing MOVE -> reward -1
# Step 17: agent Hunter_96ce8faf executing MOVE -> reward -1
# Step 18: agent Hunter_96ce8faf executing MOVE -> reward -1
# Step 19: agent Hunter_96ce8faf executing LEFT -> reward -1
# Step 20: agent Hunter_96ce8faf executing MOVE -> reward -1
# Step 21: agent Hunter_96ce8faf executing MOVE -> reward -1
# Step 22: agent Hunter_96ce8faf executing CLIMB -> reward 999
# The agent Hunter_96ce8faf succeeded!
# ┌───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │  P│  P│  P│
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │  P│  P│   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │  P│   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │  P│   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │  P│   │   │
# │ @V│   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 968 for agent Hunter_96ce8faf
# this is  (3, 4)
# World details:
#   Size: (5, 5)
#   Pits: [(3, 0), (1, 1), (3, 1), (0, 2), (3, 2), (4, 2), (4, 4)]
#   Wumpus: [(3, 4)]
#   Gold: [(1, 2)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96cea0f1 executing RIGHT -> reward -1
# Step 1: agent Hunter_96cea0f1 executing MOVE -> reward -1
# Step 2: agent Hunter_96cea0f1 executing MOVE -> reward -1
# Step 3: agent Hunter_96cea0f1 executing LEFT -> reward -1
# Step 4: agent Hunter_96cea0f1 executing MOVE -> reward -1
# Step 5: agent Hunter_96cea0f1 executing MOVE -> reward -1
# Step 6: agent Hunter_96cea0f1 executing LEFT -> reward -1
# Step 7: agent Hunter_96cea0f1 executing MOVE -> reward -1
# Step 8: agent Hunter_96cea0f1 executing GRAB -> reward -1
# Step 9: agent Hunter_96cea0f1 executing RIGHT -> reward -1
# Step 10: agent Hunter_96cea0f1 executing RIGHT -> reward -1
# Step 11: agent Hunter_96cea0f1 executing MOVE -> reward -1
# Step 12: agent Hunter_96cea0f1 executing RIGHT -> reward -1
# Step 13: agent Hunter_96cea0f1 executing MOVE -> reward -1
# Step 14: agent Hunter_96cea0f1 executing MOVE -> reward -1
# Step 15: agent Hunter_96cea0f1 executing RIGHT -> reward -1
# Step 16: agent Hunter_96cea0f1 executing MOVE -> reward -1
# Step 17: agent Hunter_96cea0f1 executing MOVE -> reward -1
# Step 18: agent Hunter_96cea0f1 executing CLIMB -> reward 999
# The agent Hunter_96cea0f1 succeeded!
# ┌───┬───┬───┬───┬───┐
# │   │   │   │W  │  P│
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │  P│   │   │  P│  P│
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │  P│   │  P│   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │  P│   │
# │ @<│   │   │   │   │
# └───┴───┴───┴───┴───┘
# Episode terminated with a reward of 981 for agent Hunter_96cea0f1
# this is  (2, 0)
# World details:
#   Size: (4, 4)
#   Pits: [(1, 0), (2, 1)]
#   Wumpus: [(2, 0)]
#   Gold: [(2, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96ceb1cd executing MOVE -> reward -1
# Step 1: agent Hunter_96ceb1cd executing MOVE -> reward -1
# Step 2: agent Hunter_96ceb1cd executing MOVE -> reward -1
# Step 3: agent Hunter_96ceb1cd executing RIGHT -> reward -1
# Step 4: agent Hunter_96ceb1cd executing MOVE -> reward -1
# Step 5: agent Hunter_96ceb1cd executing MOVE -> reward -1
# Step 6: agent Hunter_96ceb1cd executing GRAB -> reward -1
# Step 7: agent Hunter_96ceb1cd executing RIGHT -> reward -1
# Step 8: agent Hunter_96ceb1cd executing RIGHT -> reward -1
# Step 9: agent Hunter_96ceb1cd executing MOVE -> reward -1
# Step 10: agent Hunter_96ceb1cd executing MOVE -> reward -1
# Step 11: agent Hunter_96ceb1cd executing LEFT -> reward -1
# Step 12: agent Hunter_96ceb1cd executing MOVE -> reward -1
# Step 13: agent Hunter_96ceb1cd executing MOVE -> reward -1
# Step 14: agent Hunter_96ceb1cd executing MOVE -> reward -1
# Step 15: agent Hunter_96ceb1cd executing CLIMB -> reward 999
# The agent Hunter_96ceb1cd succeeded!
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │  P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │  P│W  │   │
# │ @V│   │   │   │
# └───┴───┴───┴───┘
# Episode terminated with a reward of 984 for agent Hunter_96ceb1cd
# this is  (2, 2)
# World details:
#   Size: (4, 4)
#   Pits: [(2, 0), (0, 1), (3, 1), (2, 2), (3, 3)]
#   Wumpus: [(2, 2)]
#   Gold: [(2, 0)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96ceba4f executing CLIMB -> reward -1
# The agent Hunter_96ceba4f succeeded!
# ┌───┬───┬───┬───┐
# │   │   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │W P│   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │  P│   │   │  P│
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │ GP│   │
# │ @^│   │   │   │
# └───┴───┴───┴───┘
# Episode terminated with a reward of -1 for agent Hunter_96ceba4f
# this is  (5, 1)
# World details:
#   Size: (6, 6)
#   Pits: [(3, 2), (4, 2), (5, 3), (4, 4)]
#   Wumpus: [(5, 1)]
#   Gold: [(4, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 1: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 2: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 3: agent Hunter_96cedaf4 executing RIGHT -> reward -1
# Step 4: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 5: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 6: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 7: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 8: agent Hunter_96cedaf4 executing GRAB -> reward -1
# Step 9: agent Hunter_96cedaf4 executing RIGHT -> reward -1
# Step 10: agent Hunter_96cedaf4 executing RIGHT -> reward -1
# Step 11: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 12: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 13: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 14: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 15: agent Hunter_96cedaf4 executing LEFT -> reward -1
# Step 16: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 17: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 18: agent Hunter_96cedaf4 executing MOVE -> reward -1
# Step 19: agent Hunter_96cedaf4 executing CLIMB -> reward 999
# The agent Hunter_96cedaf4 succeeded!
# ┌───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │  P│   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │  P│
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │  P│  P│   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │W  │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │
# │ @V│   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 980 for agent Hunter_96cedaf4
# this is  (0, 3)
# World details:
#   Size: (5, 5)
#   Pits: [(2, 0), (3, 0), (0, 2), (4, 2), (4, 3)]
#   Wumpus: [(0, 3)]
#   Gold: [(2, 4)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96cedaca executing RIGHT -> reward -1
# Step 1: agent Hunter_96cedaca executing MOVE -> reward -1
# Step 2: agent Hunter_96cedaca executing LEFT -> reward -1
# Step 3: agent Hunter_96cedaca executing MOVE -> reward -1
# Step 4: agent Hunter_96cedaca executing RIGHT -> reward -1
# Step 5: agent Hunter_96cedaca executing MOVE -> reward -1
# Step 6: agent Hunter_96cedaca executing LEFT -> reward -1
# Step 7: agent Hunter_96cedaca executing MOVE -> reward -1
# Step 8: agent Hunter_96cedaca executing MOVE -> reward -1
# Step 9: agent Hunter_96cedaca executing MOVE -> reward -1
# Step 10: agent Hunter_96cedaca executing GRAB -> reward -1
# Step 11: agent Hunter_96cedaca executing LEFT -> reward -1
# Step 12: agent Hunter_96cedaca executing MOVE -> reward -1
# Step 13: agent Hunter_96cedaca executing LEFT -> reward -1
# Step 14: agent Hunter_96cedaca executing MOVE -> reward -1
# Step 15: agent Hunter_96cedaca executing MOVE -> reward -1
# Step 16: agent Hunter_96cedaca executing MOVE -> reward -1
# Step 17: agent Hunter_96cedaca executing RIGHT -> reward -1
# Step 18: agent Hunter_96cedaca executing MOVE -> reward -1
# Step 19: agent Hunter_96cedaca executing LEFT -> reward -1
# Step 20: agent Hunter_96cedaca executing MOVE -> reward -1
# Step 21: agent Hunter_96cedaca executing CLIMB -> reward 999
# The agent Hunter_96cedaca succeeded!
# ┌───┬───┬───┬───┬───┐
# │   │   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │W  │   │   │   │  P│
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │  P│   │   │   │  P│
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │  P│  P│   │
# │ @V│   │   │   │   │
# └───┴───┴───┴───┴───┘
# Episode terminated with a reward of 978 for agent Hunter_96cedaca
# this is  (3, 0)
# World details:
#   Size: (6, 6)
#   Pits: [(3, 1), (5, 1), (0, 2), (0, 3), (2, 5)]
#   Wumpus: [(3, 0)]
#   Gold: [(3, 1)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96ceda6a executing CLIMB -> reward -1
# The agent Hunter_96ceda6a succeeded!
# ┌───┬───┬───┬───┬───┬───┐
# │   │   │  P│   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │  P│   │   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │  P│   │   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │ GP│   │  P│
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │W  │   │   │
# │ @^│   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of -1 for agent Hunter_96ceda6a
# this is  (0, 3)
# World details:
#   Size: (5, 5)
#   Pits: [(3, 3), (0, 4)]
#   Wumpus: [(0, 3)]
#   Gold: [(2, 2)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96cea043 executing RIGHT -> reward -1
# Step 1: agent Hunter_96cea043 executing MOVE -> reward -1
# Step 2: agent Hunter_96cea043 executing MOVE -> reward -1
# Step 3: agent Hunter_96cea043 executing LEFT -> reward -1
# Step 4: agent Hunter_96cea043 executing MOVE -> reward -1
# Step 5: agent Hunter_96cea043 executing MOVE -> reward -1
# Step 6: agent Hunter_96cea043 executing GRAB -> reward -1
# Step 7: agent Hunter_96cea043 executing LEFT -> reward -1
# Step 8: agent Hunter_96cea043 executing MOVE -> reward -1
# Step 9: agent Hunter_96cea043 executing MOVE -> reward -1
# Step 10: agent Hunter_96cea043 executing LEFT -> reward -1
# Step 11: agent Hunter_96cea043 executing MOVE -> reward -1
# Step 12: agent Hunter_96cea043 executing MOVE -> reward -1
# Step 13: agent Hunter_96cea043 executing CLIMB -> reward 999
# The agent Hunter_96cea043 succeeded!
# ┌───┬───┬───┬───┬───┐
# │  P│   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │W  │   │   │  P│   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │   │
# │   │   │   │   │   │
# ├───┼───┼───┼───┼───┤
# │   │   │   │   │   │
# │ @V│   │   │   │   │
# └───┴───┴───┴───┴───┘
# Episode terminated with a reward of 986 for agent Hunter_96cea043
# this is  (1, 2)
# World details:
#   Size: (7, 7)
#   Pits: [(2, 0), (4, 6)]
#   Wumpus: [(1, 2)]
#   Gold: [(2, 5)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96ce9dd3 executing RIGHT -> reward -1
# Step 1: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 2: agent Hunter_96ce9dd3 executing LEFT -> reward -1
# Step 3: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 4: agent Hunter_96ce9dd3 executing RIGHT -> reward -1
# Step 5: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 6: agent Hunter_96ce9dd3 executing LEFT -> reward -1
# Step 7: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 8: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 9: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 10: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 11: agent Hunter_96ce9dd3 executing GRAB -> reward -1
# Step 12: agent Hunter_96ce9dd3 executing LEFT -> reward -1
# Step 13: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 14: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 15: agent Hunter_96ce9dd3 executing LEFT -> reward -1
# Step 16: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 17: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 18: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 19: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 20: agent Hunter_96ce9dd3 executing MOVE -> reward -1
# Step 21: agent Hunter_96ce9dd3 executing CLIMB -> reward 999
# The agent Hunter_96ce9dd3 succeeded!
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │  P│   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │W  │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │  P│   │   │   │   │
# │ @V│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 978 for agent Hunter_96ce9dd3
# this is  (0, 5)
# World details:
#   Size: (6, 6)
#   Pits: [(1, 1), (1, 2), (1, 3), (1, 4), (3, 1), (4, 1), (5, 2), (2, 3), (3, 3), (4, 4), (5, 4)]
#   Wumpus: [(0, 5)]
#   Gold: [(5, 5)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 1: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 2: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 3: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 4: agent Hunter_96ced28b executing SHOOT -> reward -10
# Step 5: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 6: agent Hunter_96ced28b executing RIGHT -> reward -1
# Step 7: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 8: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 9: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 10: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 11: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 12: agent Hunter_96ced28b executing GRAB -> reward -1
# Step 13: agent Hunter_96ced28b executing RIGHT -> reward -1
# Step 14: agent Hunter_96ced28b executing RIGHT -> reward -1
# Step 15: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 16: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 17: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 18: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 19: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 20: agent Hunter_96ced28b executing LEFT -> reward -1
# Step 21: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 22: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 23: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 24: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 25: agent Hunter_96ced28b executing MOVE -> reward -1
# Step 26: agent Hunter_96ced28b executing CLIMB -> reward 999
# The agent Hunter_96ced28b succeeded!
# ┌───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │  P│  P│
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │  P│  P│  P│   │   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │  P│   │  P│  P│   │
# │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │
# │ @V│   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 964 for agent Hunter_96ced28b
# this is  (0, 1)
# World details:
#   Size: (4, 4)
#   Pits: [(1, 1), (1, 2)]
#   Wumpus: [(0, 1)]
#   Gold: [(0, 3)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96cea010 executing SHOOT -> reward -10
# Step 1: agent Hunter_96cea010 executing MOVE -> reward -1
# Step 2: agent Hunter_96cea010 executing MOVE -> reward -1
# Step 3: agent Hunter_96cea010 executing MOVE -> reward -1
# Step 4: agent Hunter_96cea010 executing GRAB -> reward -1
# Step 5: agent Hunter_96cea010 executing RIGHT -> reward -1
# Step 6: agent Hunter_96cea010 executing RIGHT -> reward -1
# Step 7: agent Hunter_96cea010 executing MOVE -> reward -1
# Step 8: agent Hunter_96cea010 executing MOVE -> reward -1
# Step 9: agent Hunter_96cea010 executing MOVE -> reward -1
# Step 10: agent Hunter_96cea010 executing CLIMB -> reward 999
# The agent Hunter_96cea010 succeeded!
# ┌───┬───┬───┬───┐
# │   │   │   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │  P│   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │  P│   │   │
# │   │   │   │   │
# ├───┼───┼───┼───┤
# │   │   │   │   │
# │ @V│   │   │   │
# └───┴───┴───┴───┘
# Episode terminated with a reward of 980 for agent Hunter_96cea010
# this is  (1, 3)
# World details:
#   Size: (7, 7)
#   Pits: [(1, 0), (3, 0), (0, 1), (3, 1)]
#   Wumpus: [(1, 3)]
#   Gold: [(2, 2)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96cedaa9 executing CLIMB -> reward -1
# The agent Hunter_96cedaa9 succeeded!
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │W  │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │ G │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│   │   │  P│   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │  P│   │   │   │
# │ @^│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of -1 for agent Hunter_96cedaa9
# this is  (3, 3)
# World details:
#   Size: (7, 7)
#   Pits: [(1, 1), (1, 2), (1, 3), (1, 4), (1, 5), (2, 5), (3, 5), (4, 5), (5, 5), (5, 4), (5, 3), (5, 2), (5, 1), (4, 1), (3, 1), (2, 1)]
#   Wumpus: [(3, 3)]
#   Gold: [(6, 6)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96ff4e43 executing RIGHT -> reward -1
# Step 1: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 2: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 3: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 4: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 5: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 6: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 7: agent Hunter_96ff4e43 executing LEFT -> reward -1
# Step 8: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 9: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 10: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 11: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 12: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 13: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 14: agent Hunter_96ff4e43 executing GRAB -> reward -1
# Step 15: agent Hunter_96ff4e43 executing LEFT -> reward -1
# Step 16: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 17: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 18: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 19: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 20: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 21: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 22: agent Hunter_96ff4e43 executing LEFT -> reward -1
# Step 23: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 24: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 25: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 26: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 27: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 28: agent Hunter_96ff4e43 executing MOVE -> reward -1
# Step 29: agent Hunter_96ff4e43 executing CLIMB -> reward 999
# The agent Hunter_96ff4e43 succeeded!
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│  P│  P│  P│  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │W  │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│  P│  P│  P│  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │ @V│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 970 for agent Hunter_96ff4e43
# this is  (3, 0)
# World details:
#   Size: (7, 7)
#   Pits: [(1, 1), (1, 2), (1, 3), (1, 4), (1, 5), (2, 5), (3, 5), (4, 5), (5, 5), (5, 4), (5, 3), (5, 2), (5, 1), (4, 1), (3, 1), (2, 1)]
#   Wumpus: [(3, 0)]
#   Gold: [(6, 5)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 1: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 2: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 3: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 4: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 5: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 6: agent Hunter_96ff4eb2 executing RIGHT -> reward -1
# Step 7: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 8: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 9: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 10: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 11: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 12: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 13: agent Hunter_96ff4eb2 executing RIGHT -> reward -1
# Step 14: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 15: agent Hunter_96ff4eb2 executing GRAB -> reward -1
# Step 16: agent Hunter_96ff4eb2 executing RIGHT -> reward -1
# Step 17: agent Hunter_96ff4eb2 executing RIGHT -> reward -1
# Step 18: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 19: agent Hunter_96ff4eb2 executing LEFT -> reward -1
# Step 20: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 21: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 22: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 23: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 24: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 25: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 26: agent Hunter_96ff4eb2 executing LEFT -> reward -1
# Step 27: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 28: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 29: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 30: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 31: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 32: agent Hunter_96ff4eb2 executing MOVE -> reward -1
# Step 33: agent Hunter_96ff4eb2 executing CLIMB -> reward 999
# The agent Hunter_96ff4eb2 succeeded!
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│  P│  P│  P│  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│   │   │   │  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │  P│  P│  P│  P│  P│   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │W  │   │   │   │
# │ @V│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 966 for agent Hunter_96ff4eb2
# this is  (0, 3)
# World details:
#   Size: (7, 7)
#   Pits: [(0, 1), (0, 2), (1, 2), (0, 3), (1, 3), (2, 3), (0, 4), (1, 4), (0, 5)]
#   Wumpus: [(0, 3)]
#   Gold: [(0, 6)]
#   Exits: [(0, 0)]
#   Blocks: []
# Step 0: agent Hunter_96ff47df executing RIGHT -> reward -1
# Step 1: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 2: agent Hunter_96ff47df executing LEFT -> reward -1
# Step 3: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 4: agent Hunter_96ff47df executing RIGHT -> reward -1
# Step 5: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 6: agent Hunter_96ff47df executing LEFT -> reward -1
# Step 7: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 8: agent Hunter_96ff47df executing RIGHT -> reward -1
# Step 9: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 10: agent Hunter_96ff47df executing LEFT -> reward -1
# Step 11: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 12: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 13: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 14: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 15: agent Hunter_96ff47df executing LEFT -> reward -1
# Step 16: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 17: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 18: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 19: agent Hunter_96ff47df executing GRAB -> reward -1
# Step 20: agent Hunter_96ff47df executing RIGHT -> reward -1
# Step 21: agent Hunter_96ff47df executing RIGHT -> reward -1
# Step 22: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 23: agent Hunter_96ff47df executing RIGHT -> reward -1
# Step 24: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 25: agent Hunter_96ff47df executing LEFT -> reward -1
# Step 26: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 27: agent Hunter_96ff47df executing RIGHT -> reward -1
# Step 28: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 29: agent Hunter_96ff47df executing LEFT -> reward -1
# Step 30: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 31: agent Hunter_96ff47df executing RIGHT -> reward -1
# Step 32: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 33: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 34: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 35: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 36: agent Hunter_96ff47df executing RIGHT -> reward -1
# Step 37: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 38: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 39: agent Hunter_96ff47df executing MOVE -> reward -1
# Step 40: agent Hunter_96ff47df executing CLIMB -> reward 999
# The agent Hunter_96ff47df succeeded!
# ┌───┬───┬───┬───┬───┬───┬───┐
# │   │   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│  P│   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │W P│  P│  P│   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│  P│   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │  P│   │   │   │   │   │   │
# │   │   │   │   │   │   │   │
# ├───┼───┼───┼───┼───┼───┼───┤
# │   │   │   │   │   │   │   │
# │ @<│   │   │   │   │   │   │
# └───┴───┴───┴───┴───┴───┴───┘
# Episode terminated with a reward of 959 for agent Hunter_96ff47df

# %%
dict(result)
# Out:
# {'../data\\wumpus_world-00.json': ['6.64 ms'],
#  '../data\\wumpus_world-01.json': ['3.18 ms'],
#  '../data\\wumpus_world-02.json': ['2.45 ms'],
#  '../data\\wumpus_world-03.json': ['2.71 ms'],
#  '../data\\wumpus_world-04.json': ['2.31 ms'],
#  '../data\\wumpus_world-05.json': ['4.93 ms'],
#  '../data\\wumpus_world-06.json': ['2.42 ms'],
#  '../data\\wumpus_world-07.json': ['1.54 ms'],
#  '../data\\wumpus_world-08.json': ['2.31 ms'],
#  '../data\\wumpus_world-09.json': ['5.34 ms'],
#  '../data\\wumpus_world-kill_to_grab.json': ['3.04 ms'],
#  '../data\\wumpus_world-opt_kill.json': ['1.64 ms'],
#  '../data\\wumpus_world_custom_00.json': ['1.75 ms'],
#  '../data\\wumpus_world_custom_01.json': ['3.58 ms'],
#  '../data\\wumpus_world_custom_02.json': ['2.86 ms'],
#  '../data\\wumpus_world_custom_03.json': ['5.44 ms']}
